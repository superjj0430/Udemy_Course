# %% [markdown]
# ![array_reverse.PNG](attachment:array_reverse.PNG)

# %% [markdown]
# reference:
# https://algorithms-data-structures-python.readthedocs.io/en/latest/2-arrays/4-reverse_array.html

# %%
x1 = [1,2,3,4,5]

x2 = [1,2,3,4]


def array_reverse(arr):
    start = 0
    end = len(arr)-1
    
    while start != end and start < end:
        
#         method 1
#         tmp = arr[start]
#         arr[start] = arr[end]
#         arr[end] = tmp

#         method 2(python only)
#         arr[start], arr[end] = arr[end], arr[start]

        start+=1
        end-=1
    return arr

array_reverse(x2)
# Out:
# [1, 2, 3, 4]

# %%
# method 3(python only)
def array_reverse_python(arr):
    arr = arr[::-1]
    return arr

# %%
 1534236469 > 2**31 - 1
# Out:
# False
